# %%
# module_ARIMA.py
# This module runs an ARIMA model on the data and forecasts the next 12 periods.
# packages import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_excel('test_data/IPC.xlsx')
data
# Out:
#          Meses     IPC
# 0   2016-11-01   92.54
# 1   2016-12-01   92.91
# 2   2017-01-01   93.87
# 3   2017-02-01   94.82
# 4   2017-03-01   95.26
# ..         ...     ...
# 106 2025-09-01  151.96
# 107 2025-10-01  152.24
# 108 2025-11-01  152.35
# 109 2025-12-01  152.78
# 110 2026-01-01  154.64
#
# [111 rows x 2 columns]

# %%
plt.plot(data['Meses'], data['IPC'])
plt.show()

# %%
result = adfuller(data['IPC'])
print(result[1])  # p-value
# Out:
# 0.9647253933249132
